# %%
from propofol.patient import EleveldPatient as Patient
from propofol.recommend_regimen import recommend_propofol_regimen
patient_sim = Patient(
    age=35,
    height=170,
    weight=70,
    sex="male",
    opiates=False,
    base_pp=53.6,
    base_hr=70.0,
    base_map=90.0,
)

rec = recommend_propofol_regimen(
    patient=patient_sim,
    baseline_map=90.0,
    hemo_model="Su2022",
    use_bsv=False,
    mode= "auto",
)
# Out:
# ================ RECOMMENDED REGIMEN ================
#
# Mode: auto
# Bolus: 185 mg (2.643 mg/kg)
#
# Minute-wise maintenance schedule (mg/kg/h):
#   minute 00-01: pause
#   minute 01-02: pause
#   minute 02-03: pause
#   minute 03-04: pause
#   minute 04-05: pause
#   minute 05-06: 4.02
#   minute 06-07: 4.02
#   minute 07-08: 8.39
#   minute 08-09: 8.39
#   minute 09-10: 8.39
#   minute 10-11: 8.99
#   minute 11-12: 8.99
#   minute 12-13: 8.99
#   minute 13-14: 8.99
#   minute 14-15: 8.99
#
# Performance:
#   time to BIS <= 60: 0.65 min
